# %% [markdown]
# #  Example 4: Cation exchange- flushing of a sodium-potassium nitrate solution with calcium chloride
# This modelling example is the first among several examples that include and demonstrate ion-exchanging reactions in flow-through systems. The example was originally used as PHREEQM (Nienhuis et al., 1994) test case, and is also included in the PHREEQC-3 documentation (Parkhurst and Appelo, 2013) as Example 11. Further discussion can be found in (Appelo and Postma, 1993), where it forms Example 10.13, and in (Appelo, 1994). The one-dimensional simulation problem describes a hypothetical column experiment where porewater containing sodium (Na<sup>+</sup>), potassium (K<sup>+</sup>) and nitrate (NO<sup>-</sup><sub>3</sub>) in equilibrium with exchangeable cations is flushed by a calcium chloride (CaCl<sub>2</sub>) solution

# %%
from pathlib import Path
import os
from modflowapi.extensions import ApiSimulation
from modflowapi import Callbacks
# from workflow import *
from datetime import datetime
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#add mf6rtm path to the system
import flopy
from mf6rtm import utils, mf6rtm, mup3d
import re
import difflib

prefix = 'ex4'
DT_FMT = "%Y-%m-%d %H:%M:%S"
dataws = os.path.join("data")
databasews = os.path.join("database")


#stuff to compare outputs from pht3d and mf6rtm

def find_closest_match(query, dictionary):
    closest_match = difflib.get_close_matches(query, dictionary.keys(), n=1)
    if closest_match:
        return closest_match[0]
    else:
        return None
    
def calc_rows_from_ncol(variables, ncols=4):
    '''
    Calculates number of rows for subplots
    from ncols and len of variables to plot.

    Parameters:
        variables (list or sequence): list of variables to plot
        ncols (int): number of columns to plot
    '''
    n_subplots = len(variables)
    # calculate number of rows
    nrows = n_subplots // ncols + (n_subplots % ncols > 0)
    return nrows

# %% [markdown]
# ## Flow and Transport Setup

# %%
### Model params and setup

# General
length_units = "meters"
time_units = "days"

# Model discretization
nlay = 1  # Number of layers
Lx = 0.08 #m
ncol = 40 # Number of columns
nrow = 1  # Number of rows
delr = Lx/ncol #10.0  # Column width ($m$)
delc = 1.0  # Row width ($m$)
top = 1.  # Top of the model ($m$)
# botm = 0.0  # Layer bottom elevations ($m$)
zbotm = 0.
botm = np.linspace(top, zbotm, nlay + 1)[1:]

#tdis
nper = 1  # Number of periods
tstep = 0.002 *0.5 # Time step ($days$)
perlen = 0.24  # Simulation time ($days$)
nstp = perlen/tstep #100.0
dt0 = perlen / nstp
tdis_rc = []
tdis_rc.append((perlen, nstp, 1.0))

#injection
q = 1 #injection rate m3/d
wel_spd = [[(0,0,0), q]]


#hydraulic properties
prsity = 1 # Porosity
k11 = 1.0  # Horizontal hydraulic conductivity ($m/d$)
k33 = k11  # Vertical hydraulic conductivity ($m/d$)
strt = np.ones((nlay, nrow, ncol), dtype=float)*1
# two chd one for tailings and conc and other one for hds 

# two chd one for tailings and conc and other one for hds 
r_hd = 1
strt = np.ones((nlay, nrow, ncol), dtype=float)

chdspd = [[(i, 0, ncol-1), r_hd] for i in range(nlay)] # Constant head boundary $m$
# chdspd.extend([(i, 0, ncol - 1), r_hd] for i in range(nlay))

# chdspd_tail = [[(i, 0, 0), l_hd] for i in range(0,3)]

#transport
dispersivity = 0.002 # Longitudinal dispersivity ($m$)
disp_tr_vert = dispersivity*0.1 # Transverse vertical dispersivity ($m$)


icelltype = 1  # Cell conversion type
# ibound = np.ones((nlay, nrow, ncol), dtype=int)
# ibound[:, 0, -1] = -1
# ibound[:, 0, 0] = -1

# Set solver parameter values (and related)
nouter, ninner = 300, 600
hclose, rclose, relax = 1e-6, 1e-6, 1.0

# %% [markdown]
# ## Initialize Chemistry in Domain

# %%
files = [f for f in os.listdir(dataws) if f.startswith(prefix)]

solutionsdf = pd.read_csv(os.path.join(dataws,f"{prefix}_solutions.csv"), comment = '#',  index_col = 0)

# solutions = utils.solution_csv_to_dict(os.path.join(dataws,f"{prefix}_solutions.csv"))
solutions = utils.solution_df_to_dict(solutionsdf)

# %%
#assign solutions to grid
##TODO: need to get grid as disv from gwf; need gwf disv before setting chemistry initial conditions
sol_ic = np.ones((nlay, nrow, ncol), dtype=float)
# sol_ic = 1
#add solutions to clss
##TODO: is solution.shape = nlay,nrow,ncol? does solutions assume structured grid?
solution = mup3d.Solutions(solutions)
solution.set_ic(sol_ic)

excdf = pd.read_csv(os.path.join(dataws,f"{prefix}_exchange.csv"), comment = '#',  index_col = 0)
exchangerdic = utils.solution_df_to_dict(excdf)

exchanger = mup3d.ExchangePhases(exchangerdic)
exchanger.set_ic(np.ones((nlay, nrow, ncol), dtype=float))

#create model class
model = mup3d.Mup3d(prefix,solution, nlay, nrow, ncol)

#set model workspace
model.set_wd(os.path.join(f'{prefix}',f'mf6rtm'))

#set database
database = os.path.join(databasews, f'pht3d_datab.dat')
model.set_database(database)

model.set_exchange_phases(exchanger)

#get postfix file
postfix = os.path.join(dataws, f'{prefix}_postfix.phqr')
model.set_postfix(postfix)

# %%
model.initialize()
# Out:
# Using temperatue of 25.0 for all cells
# Phreeqc initialized

# %% [markdown]
# ## Initialize Inflow Chemistry

# %%
wellchem = mup3d.ChemStress('wel')
sol_spd = [2]
sol_spd
wellchem.set_spd(sol_spd)
model.set_chem_stress(wellchem)
model.wel.data
# Out:
# Initializing ChemStress
# ChemStress wel initialized
# {0: [110684.17114503868,
#   55342.085589753035,
#   -1.3109877640770236e-06,
#   0.5982258070710701,
#   1.1964516141421362,
#   0.0,
#   0.0,
#   0.0]}

# %%
for i in range(len(wel_spd)):
    wel_spd[i].extend(model.wel.data[i])
print(wel_spd)
# Out:
# [[(0, 0, 0), 1, 110684.17114503868, 55342.085589753035, -1.3109877640770236e-06, 0.5982258070710701, 1.1964516141421362, 0.0, 0.0, 0.0]]

# %%
wel_spd
# Out:
# [[(0, 0, 0),
#   1,
#   110684.17114503868,
#   55342.085589753035,
#   -1.3109877640770236e-06,
#   0.5982258070710701,
#   1.1964516141421362,
#   0.0,
#   0.0,
#   0.0]]

# %% [markdown]
# ## Build MF6 Model

# %%
def build_model(mup3d):

    #####################        GWF model           #####################
    gwfname = 'gwf'
    sim_ws = mup3d.wd
    sim = flopy.mf6.MFSimulation(sim_name=mup3d.name, sim_ws=sim_ws, exe_name='mf6')

    # Instantiating MODFLOW 6 time discretization
    flopy.mf6.ModflowTdis(sim, nper=nper, perioddata=tdis_rc, time_units=time_units)

    # Instantiating MODFLOW 6 groundwater flow model
    gwf = flopy.mf6.ModflowGwf(
        sim,
        modelname=gwfname,
        save_flows=True,
        model_nam_file=f"{gwfname}.nam",
    )

    # Instantiating MODFLOW 6 solver for flow model
    imsgwf = flopy.mf6.ModflowIms(
        sim,
        complexity="complex",
        print_option="SUMMARY",
        outer_dvclose=hclose,
        outer_maximum=nouter,
        under_relaxation="NONE",
        inner_maximum=ninner,
        inner_dvclose=hclose,
        rcloserecord=rclose,
        linear_acceleration="CG",
        scaling_method="NONE",
        reordering_method="NONE",
        relaxation_factor=relax,
        filename=f"{gwfname}.ims",
    )
    sim.register_ims_package(imsgwf, [gwf.name])

    # Instantiating MODFLOW 6 discretization package
    dis = flopy.mf6.ModflowGwfdis(
        gwf,
        length_units=length_units,
        nlay=nlay,
        nrow=nrow,
        ncol=ncol,
        delr=delr,
        delc=delc,
        top=top,
        botm=botm,
        idomain=np.ones((nlay, nrow, ncol), dtype=int),
        filename=f"{gwfname}.dis",
    )
    # set_all_data_external() is depreciated
    # dis.set_all_data_external()

    # Instantiating MODFLOW 6 node-property flow package
    npf = flopy.mf6.ModflowGwfnpf(
        gwf,
        save_flows=True,
        save_saturation = True,
        icelltype=icelltype,
        k=k11,
        k33=k33,
        save_specific_discharge=True,
        filename=f"{gwfname}.npf",
    )
    # set_all_data_external() is depreciated
    # npf.set_all_data_external()

    # sto = flopy.mf6.ModflowGwfsto(gwf, ss=1e-6, sy=0.25)

    # Instantiating MODFLOW 6 initial conditions package for flow model
    flopy.mf6.ModflowGwfic(gwf, strt=strt, filename=f"{gwfname}.ic")
    
    wel = flopy.mf6.ModflowGwfwel(
            gwf,
            stress_period_data=wel_spd,
            save_flows = True,
            auxiliary = model.components,
            pname = 'wel',
            filename=f"{gwfname}.wel"
        )
    # set_all_data_external() is depreciated
    #wel.set_all_data_external()

    # Instantiating MODFLOW 6 constant head package
    chd = flopy.mf6.ModflowGwfchd(
        gwf,
        maxbound=len(chdspd),
        stress_period_data=chdspd,
        # auxiliary=mup3d.components,
        save_flows=False,
        pname="CHD",
        filename=f"{gwfname}.chd",
    )
    # set_all_data_external() is depreciated
    #chd.set_all_data_external()

    # Instantiating MODFLOW 6 output control package for flow model
    oc_gwf = flopy.mf6.ModflowGwfoc(
        gwf,
        head_filerecord=f"{gwfname}.hds",
        budget_filerecord=f"{gwfname}.cbb",
        headprintrecord=[("COLUMNS", 10, "WIDTH", 15, "DIGITS", 6, "GENERAL")],
        saverecord=[("HEAD", "ALL"), ("BUDGET", "ALL")],
        printrecord=[("HEAD", "LAST"), ("BUDGET", "LAST")],
    )
    
    #####################           GWT model          #####################
    for c in mup3d.components:
        print(f'Setting model for component: {c}')
        gwtname = c
        
        # Instantiating MODFLOW 6 groundwater transport package
        gwt = flopy.mf6.MFModel(
            sim,
            model_type="gwt6",
            modelname=gwtname,
            model_nam_file=f"{gwtname}.nam"
        )

        # create iterative model solution and register the gwt model with it
        print('--- Building IMS package ---')
        imsgwt = flopy.mf6.ModflowIms(
            sim,
            print_option="SUMMARY",
            outer_dvclose=hclose,
            outer_maximum=nouter,
            under_relaxation="NONE",
            inner_maximum=ninner,
            inner_dvclose=hclose,
            rcloserecord=rclose,
            linear_acceleration="BICGSTAB",
            scaling_method="NONE",
            reordering_method="NONE",
            relaxation_factor=relax,
            filename=f"{gwtname}.ims",
        )
        sim.register_ims_package(imsgwt, [gwt.name])

        print('--- Building DIS package ---')
        dis = gwf.dis

        # create grid object
        dis = flopy.mf6.ModflowGwtdis(
            gwt,
            length_units=length_units,
            nlay=nlay,
            nrow=nrow,
            ncol=ncol,
            delr=delr,
            delc=delc,
            top=top,
            botm=botm,
            idomain=np.ones((nlay, nrow, ncol), dtype=int),
            filename=f"{gwtname}.dis",
        )
        # set_all_data_external() is depreciated
        #dis.set_all_data_external()

         
        ic = flopy.mf6.ModflowGwtic(gwt, strt=mup3d.sconc[c], filename=f"{gwtname}.ic")
        # set_all_data_external() is depreciated
        #ic.set_all_data_external()
        
        # Instantiating MODFLOW 6 transport source-sink mixing package
        sourcerecarray = ['wel', 'aux', f'{c}']
        # sourcerecarray = [()]
        ssm = flopy.mf6.ModflowGwtssm(
            gwt, 
            sources=sourcerecarray, 
            save_flows=True,
            print_flows=True,

            filename=f"{gwtname}.ssm"
        )
        # set_all_data_external() is depreciated
        #ssm.set_all_data_external()
        # Instantiating MODFLOW 6 transport adv package
        print('--- Building ADV package ---')
        adv = flopy.mf6.ModflowGwtadv(
            gwt,
            scheme="tvd",
        )

        # Instantiating MODFLOW 6 transport dispersion package
        alpha_l = np.ones(shape=(nlay, nrow, ncol))*dispersivity  # Longitudinal dispersivity ($m$)
        ath1 = np.ones(shape=(nlay, nrow, ncol))*dispersivity*0.1 # Transverse horizontal dispersivity ($m$)
        atv = np.ones(shape=(nlay, nrow, ncol))*dispersivity*0.1   # Transverse vertical dispersivity ($m$)

        print('--- Building DSP package ---')
        dsp = flopy.mf6.ModflowGwtdsp(
            gwt,
            xt3d_off=True,
            alh=alpha_l,
            ath1=ath1,
            atv = atv,
            # diffc = diffc,
            filename=f"{gwtname}.dsp",
        )
        # set_all_data_external() is depreciated
        #dsp.set_all_data_external()

        # Instantiating MODFLOW 6 transport mass storage package (formerly "reaction" package in MT3DMS)
        print('--- Building MST package ---')

        first_order_decay = None

        mst = flopy.mf6.ModflowGwtmst(
            gwt,
            porosity=prsity,
            first_order_decay=first_order_decay,
            filename=f"{gwtname}.mst",
        )
        # set_all_data_external() is depreciated
        #mst.set_all_data_external()

        print('--- Building OC package ---')

        # Instantiating MODFLOW 6 transport output control package
        oc_gwt = flopy.mf6.ModflowGwtoc(
            gwt,
            budget_filerecord=f"{gwtname}.cbb",
            concentration_filerecord=f"{gwtname}.ucn",
            concentrationprintrecord=[("COLUMNS", 10, "WIDTH", 15, "DIGITS", 10, "GENERAL")
                                        ],
            saverecord=[("CONCENTRATION", "ALL"), 
                        ("BUDGET", "ALL")
                        ],
            printrecord=[("CONCENTRATION", "ALL"), 
                            ("BUDGET", "ALL")
                            ],
        )

        # Instantiating MODFLOW 6 flow-transport exchange mechanism
        flopy.mf6.ModflowGwfgwt(
            sim,
            exgtype="GWF6-GWT6",
            exgmnamea=gwfname,
            exgmnameb=gwtname,
            filename=f"{gwtname}.gwfgwt",
        )

    sim.write_simulation()
    utils.prep_bins(sim_ws, src_path=os.path.join('..','bin'))
    
    return sim

# %%
sim = build_model(model)
# Out:
# Setting model for component: H
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# Setting model for component: O
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# Setting model for component: Charge
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# Setting model for component: Ca
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# Setting model for component: Cl
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# Setting model for component: K
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# Setting model for component: N
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# Setting model for component: Na
# --- Building IMS package ---
# --- Building DIS package ---
# --- Building ADV package ---
# --- Building DSP package ---
# --- Building MST package ---
# --- Building OC package ---
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing solution package ims_0...
#   writing solution package ims_1...
#   writing solution package ims_2...
#   writing solution package ims_3...
#   writing solution package ims_4...
#   writing solution package ims_5...
#   writing solution package ims_6...
#   writing solution package ims_7...
#   writing package H.gwfgwt...
#   writing package O.gwfgwt...
#   writing package Charge.gwfgwt...
#   writing package Ca.gwfgwt...
#   writing package Cl.gwfgwt...
#   writing package K.gwfgwt...
#   writing package N.gwfgwt...
#   writing package Na.gwfgwt...
#   writing model gwf...
#     writing model name file...
#     writing package dis...
#     writing package npf...
#     writing package ic...
#     writing package wel...
# INFORMATION: maxbound in ('gwf6', 'wel', 'dimensions') changed to 1 based on size of stress_period_data
#     writing package chd...
#     writing package oc...
#   writing model H...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...
#   writing model O...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...
#   writing model Charge...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...
#   writing model Ca...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...
#   writing model Cl...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...
#   writing model K...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...
#   writing model N...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...
#   writing model Na...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package ssm...
#     writing package adv...
#     writing package dsp...
#     writing package mst...
#     writing package oc...

# %%
# mf6rtm.solve(model.wd)
model.run()
# Out:
# Starting transport solution at 2025-03-18 16:05:17
# Starting solution at 2025-03-18 16:05:17
# Transport loop            | Stress period:  1     | Time step:      1          | Running ...
# Transport loop            | Stress period:  1     | Time step:      1          | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      1          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      1          | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:17
# Transport loop            | Stress period:  1     | Time step:      2          | Running ...
# Transport loop            | Stress period:  1     | Time step:      2          | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      2          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      2          | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:17
# Transport loop            | Stress period:  1     | Time step:      3          | Running ...
# Transport loop            | Stress period:  1     | Time step:      3          | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      3          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      3          | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:17
# Transport loop            | Stress period:  1     | Time step:      4          | Running ...
# Transport loop            | Stress period:  1     | Time step:      4          | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      4          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      4          | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:18
# Transport loop            | Stress period:  1     | Time step:      5          | Running ...
# Transport loop            | Stress period:  1     | Time step:      5          | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      5          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      5          | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:18
# Transport loop            | Stress period:  1     | Time step:      6          | Running ...
# Transport loop            | Stress period:  1     | Time step:      6          | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      6          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      6          | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:18
# Transport loop            | Stress period:  1     | Time step:      7          | Running ...
# Transport loop            | Stress period:  1     | Time step:      7          | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      7          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      7          | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:18
# Transport loop            | Stress period:  1     | Time step:      8          | Running ...
# Transport loop            | Stress period:  1     | Time step:      8          | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      8          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      8          | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:19
# Transport loop            | Stress period:  1     | Time step:      9          | Running ...
# Transport loop            | Stress period:  1     | Time step:      9          | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      9          | Running ...
# Reaction loop             | Stress period:  1     | Time step:      9          | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:19
# Transport loop            | Stress period:  1     | Time step:      10         | Running ...
# Transport loop            | Stress period:  1     | Time step:      10         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      10         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      10         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:19
# Transport loop            | Stress period:  1     | Time step:      11         | Running ...
# Transport loop            | Stress period:  1     | Time step:      11         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      11         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      11         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:19
# Transport loop            | Stress period:  1     | Time step:      12         | Running ...
# Transport loop            | Stress period:  1     | Time step:      12         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      12         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      12         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:20
# Transport loop            | Stress period:  1     | Time step:      13         | Running ...
# Transport loop            | Stress period:  1     | Time step:      13         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      13         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      13         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:20
# Transport loop            | Stress period:  1     | Time step:      14         | Running ...
# Transport loop            | Stress period:  1     | Time step:      14         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      14         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      14         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:20
# Transport loop            | Stress period:  1     | Time step:      15         | Running ...
# Transport loop            | Stress period:  1     | Time step:      15         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      15         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      15         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:20
# Transport loop            | Stress period:  1     | Time step:      16         | Running ...
# Transport loop            | Stress period:  1     | Time step:      16         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      16         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      16         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:20
# Transport loop            | Stress period:  1     | Time step:      17         | Running ...
# Transport loop            | Stress period:  1     | Time step:      17         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      17         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      17         | Completed in : 0 min 0.0001 sec
#
#
# Starting solution at 2025-03-18 16:05:21
# Transport loop            | Stress period:  1     | Time step:      18         | Running ...
# Transport loop            | Stress period:  1     | Time step:      18         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      18         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      18         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:21
# Transport loop            | Stress period:  1     | Time step:      19         | Running ...
# Transport loop            | Stress period:  1     | Time step:      19         | Completed in :  0 min 0.0004 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      19         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      19         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:21
# Transport loop            | Stress period:  1     | Time step:      20         | Running ...
# Transport loop            | Stress period:  1     | Time step:      20         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      20         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      20         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:21
# Transport loop            | Stress period:  1     | Time step:      21         | Running ...
# Transport loop            | Stress period:  1     | Time step:      21         | Completed in :  0 min 0.0004 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      21         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      21         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:22
# Transport loop            | Stress period:  1     | Time step:      22         | Running ...
# Transport loop            | Stress period:  1     | Time step:      22         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      22         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      22         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:22
# Transport loop            | Stress period:  1     | Time step:      23         | Running ...
# Transport loop            | Stress period:  1     | Time step:      23         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      23         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      23         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:22
# Transport loop            | Stress period:  1     | Time step:      24         | Running ...
# Transport loop            | Stress period:  1     | Time step:      24         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      24         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      24         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:22
# Transport loop            | Stress period:  1     | Time step:      25         | Running ...
# Transport loop            | Stress period:  1     | Time step:      25         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      25         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      25         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:22
# Transport loop            | Stress period:  1     | Time step:      26         | Running ...
# Transport loop            | Stress period:  1     | Time step:      26         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      26         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      26         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:23
# Transport loop            | Stress period:  1     | Time step:      27         | Running ...
# Transport loop            | Stress period:  1     | Time step:      27         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      27         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      27         | Completed in : 0 min 0.0000 sec
#
#
# Starting solution at 2025-03-18 16:05:23
# Transport loop            | Stress period:  1     | Time step:      28         | Running ...
# Transport loop            | Stress period:  1     | Time step:      28         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      28         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      28         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:23
# Transport loop            | Stress period:  1     | Time step:      29         | Running ...
# Transport loop            | Stress period:  1     | Time step:      29         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      29         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      29         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:23
# Transport loop            | Stress period:  1     | Time step:      30         | Running ...
# Transport loop            | Stress period:  1     | Time step:      30         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      30         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      30         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:23
# Transport loop            | Stress period:  1     | Time step:      31         | Running ...
# Transport loop            | Stress period:  1     | Time step:      31         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      31         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      31         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:24
# Transport loop            | Stress period:  1     | Time step:      32         | Running ...
# Transport loop            | Stress period:  1     | Time step:      32         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      32         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      32         | Completed in : 0 min 0.0001 sec
#
#
# Starting solution at 2025-03-18 16:05:24
# Transport loop            | Stress period:  1     | Time step:      33         | Running ...
# Transport loop            | Stress period:  1     | Time step:      33         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      33         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      33         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:24
# Transport loop            | Stress period:  1     | Time step:      34         | Running ...
# Transport loop            | Stress period:  1     | Time step:      34         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      34         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      34         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:24
# Transport loop            | Stress period:  1     | Time step:      35         | Running ...
# Transport loop            | Stress period:  1     | Time step:      35         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      35         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      35         | Completed in : 0 min 0.0000 sec
#
#
# Starting solution at 2025-03-18 16:05:24
# Transport loop            | Stress period:  1     | Time step:      36         | Running ...
# Transport loop            | Stress period:  1     | Time step:      36         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      36         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      36         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:25
# Transport loop            | Stress period:  1     | Time step:      37         | Running ...
# Transport loop            | Stress period:  1     | Time step:      37         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      37         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      37         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:25
# Transport loop            | Stress period:  1     | Time step:      38         | Running ...
# Transport loop            | Stress period:  1     | Time step:      38         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      38         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      38         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:25
# Transport loop            | Stress period:  1     | Time step:      39         | Running ...
# Transport loop            | Stress period:  1     | Time step:      39         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      39         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      39         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:25
# Transport loop            | Stress period:  1     | Time step:      40         | Running ...
# Transport loop            | Stress period:  1     | Time step:      40         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      40         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      40         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:25
# Transport loop            | Stress period:  1     | Time step:      41         | Running ...
# Transport loop            | Stress period:  1     | Time step:      41         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      41         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      41         | Completed in : 0 min 0.0000 sec
#
#
# Starting solution at 2025-03-18 16:05:26
# Transport loop            | Stress period:  1     | Time step:      42         | Running ...
# Transport loop            | Stress period:  1     | Time step:      42         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      42         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      42         | Completed in : 0 min 0.0000 sec
#
#
# Starting solution at 2025-03-18 16:05:26
# Transport loop            | Stress period:  1     | Time step:      43         | Running ...
# Transport loop            | Stress period:  1     | Time step:      43         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      43         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      43         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:26
# Transport loop            | Stress period:  1     | Time step:      44         | Running ...
# Transport loop            | Stress period:  1     | Time step:      44         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      44         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      44         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:26
# Transport loop            | Stress period:  1     | Time step:      45         | Running ...
# Transport loop            | Stress period:  1     | Time step:      45         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      45         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      45         | Completed in : 0 min 0.0001 sec
#
#
# Starting solution at 2025-03-18 16:05:26
# Transport loop            | Stress period:  1     | Time step:      46         | Running ...
# Transport loop            | Stress period:  1     | Time step:      46         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      46         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      46         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:27
# Transport loop            | Stress period:  1     | Time step:      47         | Running ...
# Transport loop            | Stress period:  1     | Time step:      47         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      47         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      47         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:27
# Transport loop            | Stress period:  1     | Time step:      48         | Running ...
# Transport loop            | Stress period:  1     | Time step:      48         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      48         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      48         | Completed in : 0 min 0.0000 sec
#
#
# Starting solution at 2025-03-18 16:05:27
# Transport loop            | Stress period:  1     | Time step:      49         | Running ...
# Transport loop            | Stress period:  1     | Time step:      49         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      49         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      49         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:27
# Transport loop            | Stress period:  1     | Time step:      50         | Running ...
# Transport loop            | Stress period:  1     | Time step:      50         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      50         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      50         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:27
# Transport loop            | Stress period:  1     | Time step:      51         | Running ...
# Transport loop            | Stress period:  1     | Time step:      51         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      51         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      51         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:28
# Transport loop            | Stress period:  1     | Time step:      52         | Running ...
# Transport loop            | Stress period:  1     | Time step:      52         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      52         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      52         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:28
# Transport loop            | Stress period:  1     | Time step:      53         | Running ...
# Transport loop            | Stress period:  1     | Time step:      53         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      53         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      53         | Completed in : 0 min 0.0000 sec
#
#
# Starting solution at 2025-03-18 16:05:28
# Transport loop            | Stress period:  1     | Time step:      54         | Running ...
# Transport loop            | Stress period:  1     | Time step:      54         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      54         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      54         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:28
# Transport loop            | Stress period:  1     | Time step:      55         | Running ...
# Transport loop            | Stress period:  1     | Time step:      55         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      55         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      55         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:28
# Transport loop            | Stress period:  1     | Time step:      56         | Running ...
# Transport loop            | Stress period:  1     | Time step:      56         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      56         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      56         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:29
# Transport loop            | Stress period:  1     | Time step:      57         | Running ...
# Transport loop            | Stress period:  1     | Time step:      57         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      57         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      57         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:29
# Transport loop            | Stress period:  1     | Time step:      58         | Running ...
# Transport loop            | Stress period:  1     | Time step:      58         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      58         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      58         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:29
# Transport loop            | Stress period:  1     | Time step:      59         | Running ...
# Transport loop            | Stress period:  1     | Time step:      59         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      59         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      59         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:29
# Transport loop            | Stress period:  1     | Time step:      60         | Running ...
# Transport loop            | Stress period:  1     | Time step:      60         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      60         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      60         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:30
# Transport loop            | Stress period:  1     | Time step:      61         | Running ...
# Transport loop            | Stress period:  1     | Time step:      61         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      61         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      61         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:30
# Transport loop            | Stress period:  1     | Time step:      62         | Running ...
# Transport loop            | Stress period:  1     | Time step:      62         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      62         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      62         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:30
# Transport loop            | Stress period:  1     | Time step:      63         | Running ...
# Transport loop            | Stress period:  1     | Time step:      63         | Completed in :  0 min 0.0004 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      63         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      63         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:31
# Transport loop            | Stress period:  1     | Time step:      64         | Running ...
# Transport loop            | Stress period:  1     | Time step:      64         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      64         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      64         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:31
# Transport loop            | Stress period:  1     | Time step:      65         | Running ...
# Transport loop            | Stress period:  1     | Time step:      65         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      65         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      65         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:31
# Transport loop            | Stress period:  1     | Time step:      66         | Running ...
# Transport loop            | Stress period:  1     | Time step:      66         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      66         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      66         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:31
# Transport loop            | Stress period:  1     | Time step:      67         | Running ...
# Transport loop            | Stress period:  1     | Time step:      67         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      67         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      67         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:32
# Transport loop            | Stress period:  1     | Time step:      68         | Running ...
# Transport loop            | Stress period:  1     | Time step:      68         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      68         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      68         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:32
# Transport loop            | Stress period:  1     | Time step:      69         | Running ...
# Transport loop            | Stress period:  1     | Time step:      69         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      69         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      69         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:32
# Transport loop            | Stress period:  1     | Time step:      70         | Running ...
# Transport loop            | Stress period:  1     | Time step:      70         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      70         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      70         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:32
# Transport loop            | Stress period:  1     | Time step:      71         | Running ...
# Transport loop            | Stress period:  1     | Time step:      71         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      71         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      71         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:33
# Transport loop            | Stress period:  1     | Time step:      72         | Running ...
# Transport loop            | Stress period:  1     | Time step:      72         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      72         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      72         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:33
# Transport loop            | Stress period:  1     | Time step:      73         | Running ...
# Transport loop            | Stress period:  1     | Time step:      73         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      73         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      73         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:33
# Transport loop            | Stress period:  1     | Time step:      74         | Running ...
# Transport loop            | Stress period:  1     | Time step:      74         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      74         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      74         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:33
# Transport loop            | Stress period:  1     | Time step:      75         | Running ...
# Transport loop            | Stress period:  1     | Time step:      75         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      75         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      75         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:33
# Transport loop            | Stress period:  1     | Time step:      76         | Running ...
# Transport loop            | Stress period:  1     | Time step:      76         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      76         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      76         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:34
# Transport loop            | Stress period:  1     | Time step:      77         | Running ...
# Transport loop            | Stress period:  1     | Time step:      77         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      77         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      77         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:34
# Transport loop            | Stress period:  1     | Time step:      78         | Running ...
# Transport loop            | Stress period:  1     | Time step:      78         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      78         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      78         | Completed in : 0 min 0.0001 sec
#
#
# Starting solution at 2025-03-18 16:05:34
# Transport loop            | Stress period:  1     | Time step:      79         | Running ...
# Transport loop            | Stress period:  1     | Time step:      79         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      79         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      79         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:34
# Transport loop            | Stress period:  1     | Time step:      80         | Running ...
# Transport loop            | Stress period:  1     | Time step:      80         | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      80         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      80         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:34
# Transport loop            | Stress period:  1     | Time step:      81         | Running ...
# Transport loop            | Stress period:  1     | Time step:      81         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      81         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      81         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:35
# Transport loop            | Stress period:  1     | Time step:      82         | Running ...
# Transport loop            | Stress period:  1     | Time step:      82         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      82         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      82         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:35
# Transport loop            | Stress period:  1     | Time step:      83         | Running ...
# Transport loop            | Stress period:  1     | Time step:      83         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      83         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      83         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:35
# Transport loop            | Stress period:  1     | Time step:      84         | Running ...
# Transport loop            | Stress period:  1     | Time step:      84         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      84         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      84         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:35
# Transport loop            | Stress period:  1     | Time step:      85         | Running ...
# Transport loop            | Stress period:  1     | Time step:      85         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      85         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      85         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:36
# Transport loop            | Stress period:  1     | Time step:      86         | Running ...
# Transport loop            | Stress period:  1     | Time step:      86         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      86         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      86         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:36
# Transport loop            | Stress period:  1     | Time step:      87         | Running ...
# Transport loop            | Stress period:  1     | Time step:      87         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      87         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      87         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:36
# Transport loop            | Stress period:  1     | Time step:      88         | Running ...
# Transport loop            | Stress period:  1     | Time step:      88         | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      88         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      88         | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:05:36
# Transport loop            | Stress period:  1     | Time step:      89         | Running ...
# Transport loop            | Stress period:  1     | Time step:      89         | Completed in :  0 min 0.0004 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      89         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      89         | Completed in : 0 min 0.0005 sec
#
#
# Starting solution at 2025-03-18 16:05:36
# Transport loop            | Stress period:  1     | Time step:      90         | Running ...
# Transport loop            | Stress period:  1     | Time step:      90         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      90         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      90         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:37
# Transport loop            | Stress period:  1     | Time step:      91         | Running ...
# Transport loop            | Stress period:  1     | Time step:      91         | Completed in :  0 min 0.0004 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      91         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      91         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:37
# Transport loop            | Stress period:  1     | Time step:      92         | Running ...
# Transport loop            | Stress period:  1     | Time step:      92         | Completed in :  0 min 0.0004 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      92         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      92         | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:05:37
# Transport loop            | Stress period:  1     | Time step:      93         | Running ...
# Transport loop            | Stress period:  1     | Time step:      93         | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      93         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      93         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:37
# Transport loop            | Stress period:  1     | Time step:      94         | Running ...
# Transport loop            | Stress period:  1     | Time step:      94         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      94         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      94         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:37
# Transport loop            | Stress period:  1     | Time step:      95         | Running ...
# Transport loop            | Stress period:  1     | Time step:      95         | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      95         | Running ...
# Reaction loop             | Stress period:  1     | Time step:      95         | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:05:38
# Transport loop            | Stress period:  1     | Time step:      96         | Running ...
# ...
# Transport loop            | Stress period:  1     | Time step:      216        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      216        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      216        | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:06:01
# Transport loop            | Stress period:  1     | Time step:      217        | Running ...
# Transport loop            | Stress period:  1     | Time step:      217        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      217        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      217        | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:06:01
# Transport loop            | Stress period:  1     | Time step:      218        | Running ...
# Transport loop            | Stress period:  1     | Time step:      218        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      218        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      218        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:02
# Transport loop            | Stress period:  1     | Time step:      219        | Running ...
# Transport loop            | Stress period:  1     | Time step:      219        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      219        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      219        | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:06:02
# Transport loop            | Stress period:  1     | Time step:      220        | Running ...
# Transport loop            | Stress period:  1     | Time step:      220        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      220        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      220        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:02
# Transport loop            | Stress period:  1     | Time step:      221        | Running ...
# Transport loop            | Stress period:  1     | Time step:      221        | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      221        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      221        | Completed in : 0 min 0.0004 sec
#
#
# Starting solution at 2025-03-18 16:06:02
# Transport loop            | Stress period:  1     | Time step:      222        | Running ...
# Transport loop            | Stress period:  1     | Time step:      222        | Completed in :  0 min 0.0003 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      222        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      222        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:02
# Transport loop            | Stress period:  1     | Time step:      223        | Running ...
# Transport loop            | Stress period:  1     | Time step:      223        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      223        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      223        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:02
# Transport loop            | Stress period:  1     | Time step:      224        | Running ...
# Transport loop            | Stress period:  1     | Time step:      224        | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      224        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      224        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:03
# Transport loop            | Stress period:  1     | Time step:      225        | Running ...
# Transport loop            | Stress period:  1     | Time step:      225        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      225        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      225        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:03
# Transport loop            | Stress period:  1     | Time step:      226        | Running ...
# Transport loop            | Stress period:  1     | Time step:      226        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      226        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      226        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:03
# Transport loop            | Stress period:  1     | Time step:      227        | Running ...
# Transport loop            | Stress period:  1     | Time step:      227        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      227        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      227        | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:06:03
# Transport loop            | Stress period:  1     | Time step:      228        | Running ...
# Transport loop            | Stress period:  1     | Time step:      228        | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      228        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      228        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:03
# Transport loop            | Stress period:  1     | Time step:      229        | Running ...
# Transport loop            | Stress period:  1     | Time step:      229        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      229        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      229        | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:06:03
# Transport loop            | Stress period:  1     | Time step:      230        | Running ...
# Transport loop            | Stress period:  1     | Time step:      230        | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      230        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      230        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:04
# Transport loop            | Stress period:  1     | Time step:      231        | Running ...
# Transport loop            | Stress period:  1     | Time step:      231        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      231        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      231        | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:06:04
# Transport loop            | Stress period:  1     | Time step:      232        | Running ...
# Transport loop            | Stress period:  1     | Time step:      232        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      232        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      232        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:04
# Transport loop            | Stress period:  1     | Time step:      233        | Running ...
# Transport loop            | Stress period:  1     | Time step:      233        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      233        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      233        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:04
# Transport loop            | Stress period:  1     | Time step:      234        | Running ...
# Transport loop            | Stress period:  1     | Time step:      234        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      234        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      234        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:04
# Transport loop            | Stress period:  1     | Time step:      235        | Running ...
# Transport loop            | Stress period:  1     | Time step:      235        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      235        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      235        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:04
# Transport loop            | Stress period:  1     | Time step:      236        | Running ...
# Transport loop            | Stress period:  1     | Time step:      236        | Completed in :  0 min 0.0001 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      236        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      236        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:05
# Transport loop            | Stress period:  1     | Time step:      237        | Running ...
# Transport loop            | Stress period:  1     | Time step:      237        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      237        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      237        | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:06:05
# Transport loop            | Stress period:  1     | Time step:      238        | Running ...
# Transport loop            | Stress period:  1     | Time step:      238        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      238        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      238        | Completed in : 0 min 0.0003 sec
#
#
# Starting solution at 2025-03-18 16:06:05
# Transport loop            | Stress period:  1     | Time step:      239        | Running ...
# Transport loop            | Stress period:  1     | Time step:      239        | Completed in :  0 min 0.0000 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      239        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      239        | Completed in : 0 min 0.0002 sec
#
#
# Starting solution at 2025-03-18 16:06:05
# Transport loop            | Stress period:  1     | Time step:      240        | Running ...
# Transport loop            | Stress period:  1     | Time step:      240        | Completed in :  0 min 0.0002 sec
# Cells sent to reactions   | 40/40
# Reaction loop             | Stress period:  1     | Time step:      240        | Running ...
# Reaction loop             | Stress period:  1     | Time step:      240        | Completed in : 0 min 0.0003 sec
#
#
#
# Transport converged successfully without any fails
#
# Reactive transport solution finished at 2025-03-18 16:06:05 --- it took:    0.80759 mins
#
# ...................,,,,,,,,,,,,,.,,.........,,,,,,,..,,,,,,,,,,,,,,,,,,,,,,.....
#
# ..................,,,,,,,,,,,,,.,,,,........,,,,,,,..,,,,,,,,,,,...,,,,,,,,,....
#
# ............,,,,,..,,,,,,,,,,,,.,,,,...........,,,,.,,,,,,,......,,,,,,,,.......
#
# ..............,,,,,,.,,,,,,,,,,,,,,,.,,...,..,,....,,,,,......,,,,,,,...........
#
# ................,,,,,,,,,,,,,,,,,,,.,,,..,,.,,....,,,,...,,,,,,,,,,,,,,,,.......
#
# ...................,,,,,,,,,,,,,,,,,,,,,.,,,,,,,,,,,,,,..,,,,,,,,,..............
#
# .......................,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...........................
#
# ........................,,,,,,,,,,,,,,,,,,,,,,,,,,,,............................
#
# ........................,,,.???????................??????......................,
#
# .........................?????????????......?????????????......................,
#
# .......................????????????????....??????????????......................,
#
# ......................??????????????????,.????????????????....................,,
#
# ......................???????.,,.???????.??????????????????...................,,
#
# ......................??????.%%%%.??????.????????..????????...................,,
#
# ........................?????.,,.??????.,???????%%%%.??????..................,,,
#
# ..........................????????????.%%,.?????,%%,??????...................,,,
#
# .........................................,...????????????...................,,,,
#
# ............................,,,,,.....??????...?????????....................,,,,
#
# ............................,,,...........?????.????????....................,,,,
#
# ...........................................?????????????....................,,,,
#
# ...............................,...........?????????????...................,,,,,
#
# .............................,,,,............???????????....................,,,,
#
# .............................,,,,,,............?????????...................,,,,,
#
# .............................,,,,,,............??..?????..................,,,,,,
#
# ............................,,,,,,,,.,...........%,.????..................,,,,,,
#
# ............................%%%,,,,,,..........,%%%,????.................,,,,,,,
#
# ...........................%%%%%,,,,,........,,%%%%%.???.................,,,,,,,
#
# ..........................,%%%%%%%,,,,,,,,,,,%%%%%%%,???...............,,,,,,,,,
#
# ..........................%%%%%%%,,%%%%%%%%,,,,,%%%%,???...............,,,,,,,,,
#
# .........................,%%%%%%%%%%%%%%%%%%%%,%%%%%,??.............,,,,,,,,,,,,
#
# .........................,%%%%%%%%%%%%%%%%%%%%%%%%%%,.?.............,,,,,,,,,,,,
#
# .........................,,,,,,%,,,,,,,,,,,,,,%%,,,,,.?.............,,,,,,,,,,,,
#
# ......................,............,,,,,,,,,.....??????...........,,,,,,,,,,,,,,
#
# .....................,%,,,,,.......????????????????????,..,,,,,..,,,,,,,,,,,,,,,
#
# ......................,,,,,,,,................????????.%.?...,,,,,,,,,,,,,,,,,,,
#
# .......................,,,%%,,,,.............???........???????..,,,,,,,,,,,,,,,
#
# ..........................,,,,,,,,,.............,,,,..?????????????..,,,,,,,,,,,
#
# .........................,..?????.,,,,,,,.,,,,%%,,....?????????????????..,,,,,,,
#
# ................?.....,.,..?????????...,,,,,,,........??????????????????????.,,,
#
# ......................,,,....??????????,,,,%%%%.?.,,..????????????????????????.,
#
#
# MR BEAKER IMPORTANT MESSAGE: MODEL RUN FINISHED BUT CHECK THE RESULTS .. THEY ARE PROLY RUBBISH
# True

# %% [markdown]
# ## Figures

# %%
wd = os.path.join(f'{prefix}', f'pht3d')
# dx = 0.01
simdf = pd.read_csv(os.path.join(wd, 'out.dat'), sep = '\t', skipinitialspace=True, index_col=[0])
simdf.drop(simdf.columns[len(simdf.columns)-1], axis=1, inplace=True)

simdf.loc[:, 'x'] = simdf['cell'] * delr

simapi = pd.read_csv(os.path.join(model.wd,'sout.csv'), sep = ',', skipinitialspace=True, index_col=[0])
simapi.loc[:, 'x'] = (simapi['cell'] + 1)*delr

#offset index of simapi by tstep
simapi.index = simapi.index + tstep

simapi

# get all ucn files in wd
ucn_files = [f for f in os.listdir(wd) if f.lower().endswith('.ucn')]
ucn_files

# get file that ends in py
pht3dpy = [f for f in os.listdir(wd) if f.endswith('py')]

#read pht3dpy file
ucndic = {}
pht3dpy = os.path.join(wd, pht3dpy[0])
with open(pht3dpy, 'r') as f:
    # print(f.read())
    for l in f:
        n =re.findall(r'\d+', l.split()[-1])[-1]
        ucndic[l.split()[0].replace('_', "")] = f"PHT3D{n}.UCN"
        
for k,v in ucndic.items():
    ucn = flopy.utils.HeadFile(os.path.join(wd, v),text=f"concentration")
    results = ucn.get_alldata()
    ucndic[k] = results
timespht3d = ucn.get_times()
    
for var in simapi.columns:
    closest_match = find_closest_match(var, ucndic)
    if closest_match:
        ucndic[var] = ucndic.pop(closest_match)

wd = os.path.join(f'{prefix}',f'mf6rtm')
# get all ucn files in wd
ucn_files = [f for f in os.listdir(wd) if f.lower().endswith('.ucn')]
ucn_files

ucndic_mf6 = {}
for k in ucn_files:
    ucn = flopy.utils.HeadFile(os.path.join(wd, k),text=f"concentration")
    results = ucn.get_alldata()
    ucndic_mf6[f'{k.split(".")[0]}'] = results
times = ucn.get_times()

wd = os.path.join(f'{prefix}',f'phreeqc')
# dx = 0.01
phreeqcout = pd.read_csv(os.path.join(wd, 'ex11trn.csv'), sep = '\t', skipinitialspace=True, index_col=[0])
phreeqcout.drop(phreeqcout.columns[len(phreeqcout.columns)-1], axis=1, inplace=True)

phreeqcout.loc[:, 'x'] = phreeqcout['cell'] * delr

# %%
pncol=2
variables = list(simapi.iloc[:,1:-1 ].columns) #dissolved only

pnrow = calc_rows_from_ncol(variables, pncol)

mf6df = simapi[simapi['cell'] == simapi['cell'].max()].copy()
pht3df = simdf[simdf['cell'] == simdf['cell'].max()].copy()
phreeqdf = phreeqcout[phreeqcout['cell'] == phreeqcout['cell'].max()].copy()

colors = ['purple', 'r', 'g', 'b']

fig, axs = plt.subplots(1,1, figsize = (6.3, 6.3))
ax = axs
[ax.plot(mf6df.index, mf6df.loc[:, var]*1000, label = f"{var} mf6rtm", c = colors[variables.index(var)]) for var in variables];
[ax.scatter(phreeqdf.time_d[::4], phreeqdf.loc[:, var][::4]*1000, label = f"{var} phreeqc",  marker = 's',facecolor = 'None', edgecolors = colors[variables.index(var)]) for var in variables];
[ax.scatter(pht3df.index[::4], pht3df.loc[:, var][::4]*1000, label = f"{var} pht3d",  facecolor = 'None', edgecolors = colors[variables.index(var)]) for var in variables];

ax.set_ylabel('C (mmol L$^{-3}$)')
ax.set_xlabel('Time (d)')
ax.legend()
fig.tight_layout()
fig.savefig(os.path.join(f'{prefix}.png'), dpi = 300)

# %%
#get common keys from ucndic and ucndic_mf6
common_keys = set(ucndic.keys()).intersection(ucndic_mf6.keys())
common_keys

pncol=2
variables = common_keys

pnrow = calc_rows_from_ncol(variables, pncol)



fig, axs = plt.subplots(pnrow,pncol, figsize = (6.3, 6.3))
for var, ax in zip(common_keys, axs.flatten()):
    ax.plot([x for x in timespht3d], ucndic[var][:,0,0,-1], label = f'PHT3D')
    ax.plot([x for x in times[:]], ucndic_mf6[var][:,0,0,-1]/1000, label = f'mf6rtm')

    #get min and max of y axis
    xmin, xmax = ax.get_ylim()
    # ax.set_ylim(xmin*.8, xmax*1.2)

    ax.set_xlabel('time (days)')
    if var not in ['pH', 'pe']:
        ax.set_ylabel('C (mol L3$^{-3}$)')
    ax.set_title(f'{var}')
    ax.ticklabel_format(useOffset=False)
    ax.legend()
fig.tight_layout()
